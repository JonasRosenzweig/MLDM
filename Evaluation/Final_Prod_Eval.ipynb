# %%
import re
import os
import pickle
import keras
import statistics

import numpy as np
import pandas as pd

from os import listdir
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing import sequence

EAN_REGEX = '(?<=\s)\d{13}(?=\s)'
MODEL_DIR = \
    r'C:\Users\mail\PycharmProjects\MLDM\Data\Final\NAME_NUM_OTHER_Oversampled\models\NAME_NUM_OTHER_OVER_WORDEMB.h5'
TOKENIZER_DIR =\
    r'C:\Users\mail\PycharmProjects\MLDM\Data\Final\NAME_NUM_OTHER_Oversampled\models\NAME_NUM_OTHER_OVER_WORDEMB.pkl'

THRESHOLD = 0.51
SAMPLE_AMOUNT = 15
RANDOM_STATE = 7
TARGETS = ['PROD_NAME', 'PROD_NUM', 'OTHER']
model = keras.models.load_model(MODEL_DIR)
tokenizer = pickle.load(open(TOKENIZER_DIR, 'rb'))
le = LabelEncoder()
print('Model, Tokenizer and LabelEncoder loaded.')

def predictClass(text, tok, model):
    text_pad = sequence.pad_sequences(tok.texts_to_sequences([text]), maxlen=300)
    predict_x = model.predict(text_pad)
    predict_class = np.argmax(predict_x, axis=1)
    score = le.inverse_transform(predict_class)
    prediction = score[0]
    return prediction

PATH = r'C:\Users\mail\Downloads\data\Eval Datasets'
list_files = listdir(PATH)
k = 0
eval_list = []
percent_list = []
percent_list_known = []


def evaluate(num):
    correct = 0
    dataset_filename = os.listdir(PATH)[num]
    print('________________________________________________________________________')
    print('----------{}----------'.format(dataset_filename))
    dataset_path = os.path.join("../..", PATH, dataset_filename)
    df = pd.read_csv(dataset_path, error_bad_lines=False, engine='c',
                 encoding='ISO-8859-14', low_memory=False, dtype=str)
    if len(df.index) >= SAMPLE_AMOUNT:
        try:
            df = df.sample(SAMPLE_AMOUNT,
                           random_state=RANDOM_STATE)
        except ValueError:
            pass
    df = df.reset_index(drop=True)
    column_headers = list(df.columns)
    # list of list of predictions including original column name
    predictions_map = list(map(lambda item: [item], column_headers))

    # list of list of predictions only - populate now then popped later
    predictions_only = list(map(lambda item: [item], column_headers))

    map_list = []
    maps_object = []
    Predictions = []
    Certainty = []
    manual_maps_list = []

    for n in range(len(column_headers)):
        print('----------Mapping column {num} of {len}----------'
              .format(num=n+1, len=len(column_headers)))
        df_select = df[column_headers[n]]
        # sequence padding and tokenization of data requires string type
        df_select = df_select.astype(str)
        multiple_predictions = []
        multiple_certainties = []

        for m in range(len(df_select)):
            class_predictions =[]
            targets = TARGETS
            targets = le.fit_transform(targets)
            data = df_select[m]
            if re.search(EAN_REGEX, data):
                predicted_class = 'PROD_BARCODE_NUM'
            elif len(data) > 200 or data == 'nan':
                predicted_class = 'OTHER'
            else:
                predicted_class = predictClass(data, tokenizer, model)
            predictions_map[n].append(predicted_class)
            predictions_only[n].append(predicted_class)
            print('Data: {data}, Class Prediction: {prediction}'
                  .format(data=data, prediction=predicted_class))

        predictions_only[n].pop(0)
        column_predictions = (predictions_only[n])
        column_predictions_series = pd.Series(column_predictions)
        column_predictions_count = column_predictions_series.value_counts()
        print('----------Column Mapping Summary----------')
        print('column predictions:', column_predictions)
        #print('column predictions series:', column_predictions_series)
        #print('column predictions count:', column_predictions_count)
        print('predicted class:', column_predictions_count.index[0])
        print('number of classifications:', column_predictions_count.iloc[0])
        print('actual class:', manual_maps[num][n])

        if column_predictions_count.iloc[0] > len(df_select) * THRESHOLD:
            print(column_predictions_count.index[0], 'is the Majority Predicted Class.')
            print('The majority class is: {pred}; {num_pred} of {len} predictions.'
                  '\nOriginal Class: {origin}'
                  .format(pred=column_predictions_count.index[0],
                          num_pred=column_predictions_count.iloc[0],
                          len=len(df_select),
                          origin=column_headers[n]))
            Predictions.append(column_predictions_count.index[0])
            Certainty.append(100)

        else:
            print('There is no Majority Predicted Class above the threshold.'
                  '\nOriginal Class: {origin}'
                  .format(origin=column_headers[n]))
            for i in range(len(column_predictions_count)):
                print('Predicted class {i}: {pred}; {num_pred} of {len} predictions.'
                      .format(i=i+1,
                              pred=column_predictions_count.index[i],
                              num_pred=column_predictions_count.iloc[i],
                              len=len(df_select)))
                multiple_predictions.append(column_predictions_count.index[i])
                multiple_certainties.append(column_predictions_count.iloc[i] / len(df_select) * 100)
            Predictions.append(multiple_predictions)
            Certainty.append(multiple_certainties)
        if column_predictions_count.index[0] == manual_maps[num][n]:
                correct +=1
        print('________________________________________________')

    print('----------Dataset Mapping Summary----------')
    percent = correct/len(column_headers)*100
    print('Correctly mapped columns: {correct}/{total}'.format(correct=correct, total=len(column_headers)))
    print('Correctly mapped column percentage: {percent}'.format(percent=percent))
    percent_list.append(percent)
    print('map list:', predictions_map)
    print('predictions only:', predictions_only)
    for item in range(len(manual_maps[num])):
        temp = manual_maps[num][item]
        manual_maps_list.append(temp)
    print('manual map:', manual_maps_list)
    print('Predictions:', Predictions)
    print('Certainties:', Certainty)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model, Tokenizer and LabelEncoder loaded.

# %%
manual_map_A_dataset = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'PROD_BARCODE_NUM', 5: 'OTHER',
                        6: 'OTHER', 7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12 : 'OTHER',
                        13: 'OTHER', 14: 'OTHER', 15: 'OTHER', 16: 'OTHER', 17: 'OTHER'}
manual_map_A_Discount_bigbuy_da = {0: 'PROD_NUM', 1: 'OTHER', 2: 'PROD_NAME', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER'}
manual_map_A_Discount_bigbuy_en = {0: 'PROD_NUM', 1: 'OTHER', 2: 'PROD_NAME', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER'}
manual_map_A_Discount_Compressed1 = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'PROD_BARCODE_NUM', 4: 'OTHER',
                                     5: 'OTHER'}
manual_map_A_Discount_Compressed2 = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'PROD_BARCODE_NUM', 4:'OTHER'}
manual_map_A_Discount_presta_product_2399_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER', 6: 'OTHER'}
manual_map_A_Discount_presta_product_2403_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'OTHER'}
manual_map_A_Discount_presta_product_2507_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5:
    'PROD_BARCODE_NUM', 6: 'OTHER', 7: 'OTHER'}
manual_map_A_Discount_presta_product_2507_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'PROD_BARCODE_NUM', 6: 'OTHER', 7: 'OTHER'}
manual_map_A_Discount_presta_product_2570_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'PROD_BARCODE_NUM'}
manual_map_A_Discount_presta_product_2570_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'PROD_BARCODE_NUM'}
manual_map_A_Discount_presta_product_2662_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER'}
manual_map_A_Discount_presta_product_2662_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER', 6: 'OTHER'}
manual_map_A_Discount_presta_product_2678_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER'}
manual_map_A_Discount_presta_product_2678_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER', 6: 'OTHER'}
manual_map_A_Discount_presta_product_3046_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'OTHER', 6: 'PROD_BARCODE_NUM', 7: 'OTHER', 8: 'OTHER'}
manual_map_A_Discount_presta_product_3046_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'OTHER', 6: 'PROD_BARCODE_NUM', 7: 'OTHER', 8: 'OTHER'}
manual_map_Bisgaard = {0: 'PROD_BARCODE_NUM', 1: 'OTHER', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER', 7: 'OTHER',
             8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER', 13: 'OTHER', 14: 'OTHER', 15: 'OTHER',
            16: 'OTHER', 17: 'OTHER', 18: 'OTHER', 19: 'OTHER', 20: 'OTHER', 21: 'OTHER', 22: 'OTHER', 23: 'OTHER',
            24: 'OTHER'}
manual_map_Scand = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'PROD_BARCODE_NUM', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                    7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER'}
manual_map_items = {0: 'PROD_NUM', 1: 'PROD_BARCODE_NUM', 2:'PROD_NAME', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                    7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER'}
manual_map_Joha = {0: 'OTHER', 1: 'OTHER', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5: 'PROD_BARCODE_NUM', 6: 'OTHER',
                   7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER', 13: 'OTHER', 14: 'OTHER',
                   15: 'OTHER', 16: 'OTHER' }
manual_map_Modern_classic_upstart = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'PROD_BARCODE_NUM', 3: 'OTHER', 4: 'OTHER',
                                     5: 'OTHER', 6: 'OTHER', 7: 'OTHER'}
manual_map_PIF = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'PROD_BARCODE_NUM', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                  7: 'OTHER'}
manual_map_prisliste ={0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                       7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER', 13: 'OTHER',
                       14:'OTHER', 15: 'OTHER', 16: 'OTHER', 17: 'PROD_BARCODE_NUM', 18: 'OTHER'}
manual_map_VAREFIL = {0: 'PROD_NUM', 1: 'PROD_BARCODE_NUM', 2: 'PROD_NAME', 3: 'PROD_NAME', 4: 'OTHER',  5: 'OTHER',
                      6: 'OTHER'}

manual_maps = [manual_map_A_dataset, manual_map_A_Discount_bigbuy_da, manual_map_A_Discount_bigbuy_en,
               manual_map_A_Discount_Compressed1, manual_map_A_Discount_Compressed2, manual_map_A_Discount_presta_product_2399_da,
               manual_map_A_Discount_presta_product_2403_en, manual_map_A_Discount_presta_product_2507_da,
               manual_map_A_Discount_presta_product_2507_en, manual_map_A_Discount_presta_product_2570_da,
               manual_map_A_Discount_presta_product_2570_en, manual_map_A_Discount_presta_product_2662_da,
               manual_map_A_Discount_presta_product_2662_en, manual_map_A_Discount_presta_product_2678_da,
               manual_map_A_Discount_presta_product_2678_en, manual_map_A_Discount_presta_product_3046_da,
               manual_map_A_Discount_presta_product_3046_en, manual_map_Bisgaard, manual_map_Scand, manual_map_items,
              manual_map_Joha, manual_map_Modern_classic_upstart, manual_map_PIF, manual_map_prisliste, manual_map_VAREFIL]

# %%
for i in range(len(list_files)):
    evaluate(i)
#evaluate(0)
#evaluate(1)
# Out:
# ________________________________________________________________________
# ----------A_dataset.csv----------
# ----------Mapping column 1 of 18----------
# Data: 235F6X, Class Prediction: PROD_NUM
# Data: 2384TB, Class Prediction: PROD_NUM
# Data: 238EB5, Class Prediction: PROD_NUM
# Data: AJ6TU2, Class Prediction: PROD_NUM
# Data: 234DW8, Class Prediction: PROD_NUM
# Data: 2394EG, Class Prediction: PROD_NUM
# Data: 235PC7, Class Prediction: PROD_NUM
# Data: 237GB4, Class Prediction: PROD_NUM
# Data: 235AQ7, Class Prediction: PROD_NUM
# Data: AM32GN, Class Prediction: PROD_NUM
# Data: 237V58, Class Prediction: PROD_NUM
# Data: AG7Z9K, Class Prediction: PROD_NUM
# Data: 235T7E, Class Prediction: PROD_NUM
# Data: AN637D, Class Prediction: PROD_NUM
# Data: AD8V6Q, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 15
# actual class: PROD_NUM
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 15 of 15 predictions.
# Original Class: id
# ________________________________________________
# ----------Mapping column 2 of 18----------
# Data: StreetSurfing - Ripper HIC Løbehjul - Rød, Class Prediction: PROD_NUM
# Data: X-Shot - Dino Attack Dino Striker Foam Dart Blaster, Class Prediction: PROD_NAME
# Data: LEGO DOTS - Kreativt designersÃḊt (41938), Class Prediction: PROD_NAME
# Data: Rødtotterne og Tyrannos - DVD, Class Prediction: PROD_NAME
# Data: Essie - Spring 2020 Neglelak - 684 Feeling Wellies, Class Prediction: PROD_NAME
# Data: BEN 10 - Heroes & Villains - Diamondhead, Class Prediction: PROD_NAME
# Data: Prinsesse Sissi 1- DVD, Class Prediction: PROD_NAME
# Data: BRIO - Anders og Andersine-tog (32260), Class Prediction: PROD_NAME
# Data: The Survivalists, Class Prediction: PROD_NAME
# Data: Sylvanian Families - Baby Slotsbørnehave (5316), Class Prediction: PROD_NAME
# Data: Ralph Lauren - Woman EDP 50 ml + Body Lotion 75 ml + Rollerball 10 ml GavesÃḊt, Class Prediction: PROD_NAME
# Data: Aquaman - 4K Blu ray, Class Prediction: PROD_NAME
# Data: NYX Professional Makeup - California Beamin' Ansigt & Krop Flydende Highlighter - Golden Glow, Class Prediction: PROD_NAME
# Data: Staedtler - Triplus Fineliner, 30 stk (334 C30P), Class Prediction: PROD_NAME
# Data: Disneys Hercules (Blu-Ray), Class Prediction: PROD_NAME
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME']
# predicted class: PROD_NAME
# number of classifications: 14
# actual class: PROD_NAME
# PROD_NAME is the Majority Predicted Class.
# The majority class is: PROD_NAME; 14 of 15 predictions.
# Original Class: title
# ________________________________________________
# ----------Mapping column 3 of 18----------
# Data: Legetøj - Løbehjul, løbecykler og vogne - Løbehjul, Class Prediction: OTHER
# Data: Legetøj - Udendørs legetøj - Blaster og skydelegetøj, Class Prediction: PROD_NAME
# Data: Legetøj - Konstruktionslegetøj - ByggesÃḊt, Class Prediction: PROD_NUM
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Skønhed - Makeup - Negle - Neglelak, Class Prediction: OTHER
# Data: Legetøj - Figurer - Superhelte, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Biler, tog og køretøjer - Tog og togbaner - Togvogne, Class Prediction: OTHER
# Data: Spil og konsoller - Nintendo Switch - Spil, Class Prediction: OTHER
# Data: Legetøj - Dukker og dukkehuse - Dukkehuse og tilbehør - Dukkehuse, Class Prediction: OTHER
# Data: Skønhed - Parfume - ParfumesÃḊt, Class Prediction: PROD_NAME
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Skønhed - Makeup - Ansigt - Contour og highlight, Class Prediction: PROD_NAME
# Data: Legetøj - Kreativt legetøj - Tusser og penne, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'PROD_NAME', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER']
# predicted class: OTHER
# number of classifications: 11
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 11 of 15 predictions.
# Original Class: category
# ________________________________________________
# ----------Mapping column 4 of 18----------
# Data: 569, Class Prediction: PROD_NUM
# Data: 99, Class Prediction: OTHER
# Data: 206, Class Prediction: PROD_NUM
# Data: 18, Class Prediction: OTHER
# Data: 59, Class Prediction: PROD_NUM
# Data: 49, Class Prediction: PROD_NUM
# Data: 55, Class Prediction: OTHER
# Data: 99, Class Prediction: OTHER
# Data: 159, Class Prediction: OTHER
# Data: 199, Class Prediction: PROD_NUM
# Data: 349, Class Prediction: PROD_NUM
# Data: 140, Class Prediction: OTHER
# Data: 60, Class Prediction: OTHER
# Data: 129, Class Prediction: OTHER
# Data: 60, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER']
# predicted class: OTHER
# number of classifications: 9
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 9 of 15 predictions.
# Original Class: Pris
# ________________________________________________
# ----------Mapping column 5 of 18----------
# Data: 813000000000, Class Prediction: PROD_NUM
# Data: 5710000000000, Class Prediction: PROD_NUM
# Data: 5700000000000, Class Prediction: PROD_NUM
# Data: 5710000000000, Class Prediction: PROD_NUM
# Data: nan, Class Prediction: OTHER
# Data: 43377761754, Class Prediction: PROD_NUM
# Data: 5710000000000, Class Prediction: PROD_NUM
# Data: 7310000000000, Class Prediction: PROD_NUM
# Data: 5060000000000, Class Prediction: PROD_NUM
# Data: 5050000000000, Class Prediction: PROD_NUM
# Data: 3610000000000, Class Prediction: PROD_NUM
# Data: 7340000000000, Class Prediction: PROD_NUM
# Data: 801000000000, Class Prediction: PROD_NUM
# Data: 4010000000000, Class Prediction: PROD_NUM
# Data: 8720000000000, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 14
# actual class: PROD_BARCODE_NUM
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 14 of 15 predictions.
# Original Class: ean
# ________________________________________________
# ----------Mapping column 6 of 18----------
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/235F6X/6e100c5076854b6cb0f60e6118f1e360.png/f/streetsurfing-ripper-hic-loebehjul-roed.png, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/2384TB/3893b86eaf834c5a9f038941c649acf5.jpg/f/x-shot-dino-attack-dino-striker-foam-dart-blaster.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/238EB5/3f312c1775c94132bafb1d54a60f5d3c.jpg/f/lego-dots-kreativt-designersaet-41938.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/AJ6TU2/588483adba404e1ea296665e14333c7d.jpeg/f/roedtotterne-og-tyrannos-dvd.jpeg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/234DW8/8dd422ae931540dcb20fae64562cc89e.jpg/f/essie-spring-2020-neglelak-684-feeling-wellies.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/2394EG/acbd5ccdb1f04ccabc212339b6eb66ba.jpg/f/ben-10-heroes-villains-diamondhead.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/235PC7/eaa4128f8d1e4ebab79d2372415b8cb1.png/f/prinsesse-sissi-1-dvd.png, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/237GB4/24c08323fa494e29870eac5f3ada34bb.jpg/f/brio-anders-og-andersine-tog-32260.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/235AQ7/a059f15b96314e46ad86e633a2d6d94f.jpg/f/survivalists.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/AM32GN/6175667356974935be814547f58dc859.jpeg/f/sylvanian-families-baby-slotsboernehave-5316.jpeg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/237V58/99bd7ab6221d410baf552d797628f00c.jpg/f/ralph-lauren-woman-edp-50-ml-body-lotion-75-ml-rollerball-10-ml-gavesaet.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/AG7Z9K/f20939ab4014453dba88d22322dd944d.jpg/f/aquaman-4k-blu-ray.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/235T7E/8f326e0e049f4ae6abd1903e790893cd.jpg/f/nyx-professional-makeup-california-beamin-ansigt-krop-flydende-highlighter-golden-glow.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/AN637D/72c21a2aad3249d7915e53f48de99983.jpg/f/staedtler-triplus-fineliner-30-stk-334-c30p.jpg, Class Prediction: OTHER
# Data: https://scale.coolshop-cdn.com/product-media.coolshop-cdn.com/AD8V6Q/25e92f2e4be84289890425ac398bb218.jpg/f/disneys-hercules-blu-ray.jpg, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER']
# predicted class: OTHER
# number of classifications: 15
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 15 of 15 predictions.
# Original Class: image
# ________________________________________________
# ----------Mapping column 7 of 18----------
# Data: 33, Class Prediction: PROD_NUM
# Data: 52, Class Prediction: PROD_NUM
# Data: 27, Class Prediction: PROD_NUM
# Data: 205, Class Prediction: PROD_NUM
# Data: 27, Class Prediction: PROD_NUM
# Data: 22, Class Prediction: OTHER
# Data: 4, Class Prediction: PROD_NUM
# Data: 80, Class Prediction: OTHER
# Data: 10, Class Prediction: PROD_NUM
# Data: 4, Class Prediction: PROD_NUM
# Data: 69, Class Prediction: OTHER
# Data: 18, Class Prediction: OTHER
# Data: 2, Class Prediction: OTHER
# Data: 11, Class Prediction: PROD_NUM
# Data: 9, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 10
# actual class: OTHER
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 10 of 15 predictions.
# Original Class: stock
# ________________________________________________
# ----------Mapping column 8 of 18----------
# Data: StreetSurfing, Class Prediction: PROD_NUM
# Data: X-Shot, Class Prediction: OTHER
# Data: LEGO, Class Prediction: PROD_NUM
# Data: nan, Class Prediction: OTHER
# Data: Essie, Class Prediction: PROD_NUM
# Data: Ben 10, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: BRIO, Class Prediction: PROD_NUM
# Data: nan, Class Prediction: OTHER
# Data: Sylvanian Families, Class Prediction: PROD_NAME
# Data: Ralph Lauren, Class Prediction: PROD_NUM
# Data: nan, Class Prediction: OTHER
# Data: NYX Professional Makeup, Class Prediction: OTHER
# Data: Staedtler, Class Prediction: PROD_NUM
# Data: Disney, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NAME', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 7
# actual class: OTHER
# There is no Majority Predicted Class above the threshold.
# Original Class: brand
# Predicted class 1: PROD_NUM; 7 of 15 predictions.
# Predicted class 2: OTHER; 7 of 15 predictions.
# Predicted class 3: PROD_NAME; 1 of 15 predictions.
# ________________________________________________
# ----------Mapping column 9 of 18----------
# Data: 19000, Class Prediction: PROD_NUM
# Data: 488, Class Prediction: PROD_NUM
# Data: 772, Class Prediction: PROD_NUM
# Data: 100, Class Prediction: PROD_NUM
# Data: 50, Class Prediction: OTHER
# Data: 311, Class Prediction: OTHER
# Data: 100, Class Prediction: PROD_NUM
# Data: 190, Class Prediction: PROD_NUM
# Data: 60, Class Prediction: OTHER
# Data: 900, Class Prediction: PROD_NUM
# Data: 640, Class Prediction: PROD_NUM
# Data: 100, Class Prediction: PROD_NUM
# Data: 100, Class Prediction: PROD_NUM
# Data: 289, Class Prediction: OTHER
# Data: 100, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 11
# actual class: OTHER
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 11 of 15 predictions.
# Original Class: weight_g
# ________________________________________________
# ----------Mapping column 10 of 18----------
# Data: 700, Class Prediction: PROD_NUM
# Data: 400, Class Prediction: OTHER
# Data: 380, Class Prediction: PROD_NUM
# Data: 190, Class Prediction: PROD_NUM
# Data: 70, Class Prediction: OTHER
# Data: 230, Class Prediction: PROD_NUM
# Data: 190, Class Prediction: PROD_NUM
# Data: 270, Class Prediction: PROD_NUM
# Data: 170, Class Prediction: OTHER
# Data: 290, Class Prediction: PROD_NUM
# Data: 220, Class Prediction: PROD_NUM
# Data: 170, Class Prediction: OTHER
# Data: 100, Class Prediction: PROD_NUM
# Data: 180, Class Prediction: OTHER
# Data: 170, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER']
# predicted class: PROD_NUM
# number of classifications: 9
# actual class: OTHER
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 9 of 15 predictions.
# Original Class: length_mm
# ________________________________________________
# ----------Mapping column 11 of 18----------
# Data: 550, Class Prediction: PROD_NUM
# Data: 270, Class Prediction: PROD_NUM
# Data: 260, Class Prediction: PROD_NUM
# Data: 135, Class Prediction: PROD_NUM
# Data: 25, Class Prediction: PROD_NUM
# Data: 190, Class Prediction: PROD_NUM
# Data: 135, Class Prediction: PROD_NUM
# Data: 150, Class Prediction: OTHER
# Data: 105, Class Prediction: OTHER
# Data: 250, Class Prediction: PROD_NUM
# Data: 220, Class Prediction: PROD_NUM
# Data: 135, Class Prediction: PROD_NUM
# Data: 35, Class Prediction: PROD_NUM
# Data: 145, Class Prediction: OTHER
# Data: 135, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 12
# actual class: OTHER
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 12 of 15 predictions.
# Original Class: width_mm
# ________________________________________________
# ----------Mapping column 12 of 18----------
# Data: 120, Class Prediction: OTHER
# Data: 80, Class Prediction: OTHER
# Data: 50, Class Prediction: OTHER
# Data: 15, Class Prediction: PROD_NUM
# Data: 25, Class Prediction: PROD_NUM
# Data: 60, Class Prediction: OTHER
# Data: 15, Class Prediction: PROD_NUM
# Data: 50, Class Prediction: OTHER
# Data: 10, Class Prediction: PROD_NUM
# Data: 180, Class Prediction: OTHER
# Data: 50, Class Prediction: OTHER
# Data: 15, Class Prediction: PROD_NUM
# Data: 35, Class Prediction: PROD_NUM
# Data: 30, Class Prediction: OTHER
# Data: 15, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM']
# predicted class: OTHER
# number of classifications: 8
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 8 of 15 predictions.
# Original Class: height_mm
# ________________________________________________
# ----------Mapping column 13 of 18----------
# Data: 9503.00.10.00, Class Prediction: OTHER
# Data: 9503.00.99.90, Class Prediction: OTHER
# Data: 9503.00.35.00, Class Prediction: OTHER
# Data: 8523.49.10.00, Class Prediction: OTHER
# Data: 3304.30.00.00, Class Prediction: OTHER
# Data: 9503.00.49.90, Class Prediction: OTHER
# Data: 8523.49.10.00, Class Prediction: OTHER
# Data: 9503.00.30.00, Class Prediction: OTHER
# Data: 8523.49.20.00, Class Prediction: OTHER
# Data: 9503.00.61.90, Class Prediction: OTHER
# Data: 3303.00.10.00, Class Prediction: OTHER
# Data: 8523.49.10.00, Class Prediction: OTHER
# Data: 3304.99.00.00, Class Prediction: OTHER
# Data: 9503.00.10.00, Class Prediction: OTHER
# Data: 8523.49.10.00, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER']
# predicted class: OTHER
# number of classifications: 15
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 15 of 15 predictions.
# Original Class: hs_code
# ________________________________________________
# ----------Mapping column 14 of 18----------
# Data: CN, Class Prediction: PROD_NUM
# Data: CN, Class Prediction: PROD_NUM
# Data: CZ, Class Prediction: PROD_NUM
# Data: AT, Class Prediction: PROD_NUM
# Data: ES, Class Prediction: PROD_NUM
# Data: CN, Class Prediction: PROD_NUM
# Data: AT, Class Prediction: PROD_NUM
# Data: CN, Class Prediction: PROD_NUM
# Data: JP, Class Prediction: PROD_NUM
# Data: CN, Class Prediction: PROD_NUM
# Data: US, Class Prediction: OTHER
# Data: AT, Class Prediction: PROD_NUM
# Data: TW, Class Prediction: PROD_NUM
# Data: DE, Class Prediction: OTHER
# Data: AT, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 13
# actual class: OTHER
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 13 of 15 predictions.
# Original Class: country_of_origin
# ________________________________________________
# ----------Mapping column 15 of 18----------
# Data: Bloody Red, Class Prediction: OTHER
# Data: Multi, Class Prediction: PROD_NAME
# Data: Multi, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# Data: 684 Feeling Wellies, Class Prediction: PROD_NAME
# Data: BEN 10 - Diamondhead, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: Multi, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: Golden Glow, Class Prediction: PROD_NAME
# Data: Multi, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'PROD_NAME', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NAME', 'PROD_NAME', 'OTHER']
# predicted class: OTHER
# number of classifications: 9
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 9 of 15 predictions.
# Original Class: Color
# ________________________________________________
# ----------Mapping column 16 of 18----------
# Data: Rød, Class Prediction: PROD_NUM
# Data: Multi, Class Prediction: PROD_NAME
# Data: Multi, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# Data: Orange, Class Prediction: OTHER
# Data: Multi, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: Multi, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: Multi, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER']
# predicted class: OTHER
# number of classifications: 9
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 9 of 15 predictions.
# Original Class: Primary Color
# ________________________________________________
# ----------Mapping column 17 of 18----------
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: Engelsk, Class Prediction: PROD_NAME
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# Data: nan, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER']
# predicted class: OTHER
# number of classifications: 14
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 14 of 15 predictions.
# Original Class: Region
# ________________________________________________
# ----------Mapping column 18 of 18----------
# Data: <p>New trick scooter from Street Surfing. This model is ideal for beginners and practitioners who loves to make jumps and other tricks.</p>
# <p>The scooter has the following specs:</p>
# <ul><li>Aluminum box deck in 6061 lightweight aluminum 11 x 50 cm.</li><li>Height from ground to handle / bar is 83 cm</li><li>HIC compression</li><li>110mm rebound wheel with aluminum core</li><li>Abec 9 ball bearings</li><li>4 bolt aluminum clamp</li><li>Steel Bar</li><li>Fender brake</li><li>ODI grips</li><li>User weight: 100 kg</li></ul>, Class Prediction: OTHER
# Data: <p>X-Shot Dino Attack Dino Striker Foam Dart Blaster (16 Darts, 4 Eggs)<br>The new X-Shot Dino Attack range is here! Face the Dino invasion with your Dino Striker foam dart blaster. With its auto-rotating 6-dart barrel you will be able to blast incoming Dinos away with extreme accuracy. An additional 6-dart storage supplies foam flingers with maximum fire power. Join the Dino eggs together, place them down and then blast them away before they hatch! Annihilate Dino Eggs with extreme accuracy from up to 90ft / 27m away. With the Dino Striker no invader stands a chance.<br>MAXIMUM PERFORMANCE: Fires darts up to 90 ft / 27 m<br>DART CAPACITY: 6-Dart Capacity, Auto-Rotating Barrel<br>DINO EGG TARGETS: Blast Dino egg targets away before they hatch<br>DART STORAGE: 6-dart extra storage<br><br>1x X-Shot Dino Attack Dino Striker Blaster,<br>16x X-Shot Foam Darts,<br>2x Medium Eggs,<br>2x Small Eggs</p>, Class Prediction: OTHER
# Data: <p>This ultimate LEGOÂ® DOTS Creative Designer Box (41938) set is a perfect kit for crafts fans or creative kids, helping them grow their crafting and design skills and confidence with different pieces.</p>
# <p>Open-ended DIY fun<br>This set includes a magazine full of creative inspiration, loads of instructions available online at LEGO.com/buildinginstructions for making different room decor items, plus assembly guides for 5 customizable DOTS items in the magazine â a desk organizer, 2-level standing drawers, hanging message board, picture frame and a small tray. Kids can use the colored and alphabet tiles to create designs and messages on the pieces or push their creativity with an Extra DOTS â Series 5 (41932) bag or Lots of DOTS (41935) box (sold separately).</p>
# <p>The perfect arts-and-crafts kit<br>The joy of this designer box is the chance it offers kids to make their own room decor items with inspiration, tips and tricks included, helping them to show off their unique designs or share them with friends.</p>
# <ul><li>Reward a deserving child with this DIY craft LEGOÂ® DOTS Creative Designer Box (41938) kit and inspire their creativity as they boost their design skills and make their own unique pieces.</li><li>Boost a childâs imagination with 5 models, plus inspiration for many more online, and more than 650 tiles, including 72 alphabet-printed tiles to create messages on the models or other DOTS sets.</li><li>Whatâs in the box? Lots of multi-colored DOTS tiles, 5 room decor items to make and decorate, an inspirational magazine with more design ideas, and a diamond-shaped tile remover for easy redecorating.</li><li>Any child aged 7 and up with a passion for arts and crafts will love this Creative Designer Box (41938) set. The tiles and models will make a fun everyday gift for boys and girls who deserve a treat.</li><li>Decorative and useful. With endless possibilities for imaginative fun and free self-expression, this exciting DIY creative kit is perfect for young designers to practice their creations.</li><li>Give kids appealing crafts to create and use with LEGOÂ® DOTS sets. This box of tiles, models and inspiration will help encourage and build childrenâs confidence and creative skills as they have fun.</li><li>LEGOÂ® DOTS sets boost kidsâ efforts at self-expression and enhance imagination through making and customizing jewelry or room decor items, bringing the joy of LEGO play to a new group of kids.</li><li>LEGOÂ® components meet rigorous industry standards to ensure they are consistent, compatible and connect and pull apart reliably every time â itâs been that way since 1958.</li><li>LEGOÂ® components are dropped, heated, crushed, twisted and analyzed to make sure they meet strict global safety standards.</li></ul>, Class Prediction: OTHER
# Data: <p>Danish Movie Classics</p>, Class Prediction: OTHER
# Data: <p>There is no doubt that Essie's nail polishes are among the best in the world, and there is a very special reason for this. The well-defined structure, the wide color palette and the good balance between the color and shine of the polish are each in place to place Essie among the top of the world's nail polish producers. With this nail polish, you get a fast-drying and long-lasting nail polish, which is incredibly easy to apply. This is because of the professional wide brush, that easily follows the shape of the nail which ensures an easy and precise application.</p>
# <p><strong>Application:</strong></p>
# <ul><li>Clean your nails with a nail polish remover to remove grease, oil and dirt</li><li>Apply a basecoat to achieve a consistent and durable result</li><li>Shake the bottle for 30 seconds before use</li><li>Apply 1-2 thin coating strokes pr. fingernail. To avoid streaking, use the brush completely horizontally on the nail when you paint</li><li>Finish with a topcoat for best durability</li></ul>
# <p><strong>Benefits:</strong></p>
# <ul><li>Super delicious nail polish from Essie</li><li>High coverage</li><li>Short drying time</li><li>Long durability</li><li>Incredibly easy to apply</li><li>Wide brush that easily follows the shape of the nail</li><li>Precise application</li></ul>
# <p><p><strong>Essie</strong></p><p>Essie was created in 1981 by Essie Weingarten. In 1981, Essie went to Las Vegas with 12 wonderful and fashionable nail polishes to pursue the dream, and already in 1982 was the first nail polish on the market. Essie had a goal, To make women feel special and to give them the perfect manicure, and to the extent that she has made women feel.</p>
# <p>Essie is today the preferred brand for nail polish and nail care for professionals and insiders in the beauty industry, celebrities, fashion icons and beauty junkies worldwide. Essie now decorates the nails in over 100 countries.
#   </p>
# <p>For more than 35 years, Essie has inspired manicure enthusiasts with a sense of humor and style, and it is not without reason that stars like the 80's actor Joan Rivers and the English royal house have carried the nail varnishes on several occasions. Essie is also award winning for its nail polishes and related nail care products, and won her first Best of Beauty Awards in 1996 for âBest Nail Polish Colorsâ and since then, Essie has raised many more prestigious prizes home.
#   </p>
# <p>With a large assortment and variety of colors, Essie is repeatedly highlighted as a brand that affects the season's trends year after year. The first 12 colors are still found in the huge and varied range. This in itself is something of a performance. It shows that Essie has an eye for the classic and timeless. With its dedication, high standards and award-winning nail polishes and nail care products, Essie has taken the place as a natural leader in luxury beauty products. Essie plans to spoil the quality conscious and colorful manicure enthusiasts for many years to come.
# </p></p><p>Essie - Spring 2020 Nailpolish</p>, Class Prediction: OTHER
# Data: <p>Ben Tennyson, a 10-year-old boy, is on an extended summer vacation with his Grampa Max and cousin Gwen when he discovers a magical device- the Omnitrix watch. This amazing device gives Ben the ability to transform into any one of the spectacular alien heroes, each with its own unique abilities. Ben, Max and Gwen travel the country in their mobile home- the Rustbucket and have a blast beating down would-be villains along the way. Each figure comes with a matching themed accessory. Contents: I figure per pack, 1 themed accessory per pack.</p>
# <ul><li><span class=a-list-item>14 different highly detailed characters to collect!</span></li><li><span class=a-list-item>Each character comes with a themed accessory.</span></li><li><span class=a-list-item>Each articulated figure is approx. 4-5.5 inches tall.</span></li><li><span class=a-list-item>Compatible with all Ben 10 playsets!</span></li><li><span class=a-list-item>Recreate your own adventure!</span></li></ul>, Class Prediction: OTHER
# Data: <p>Prinsesse Sissi 1- DVD</p>, Class Prediction: PROD_NAME
# Data: <p>âOh boy!â: This wooden and plastic steam train with retro Disney-themed design is ready to take Donald and Daisy Duck on an exciting railway adventure â the only question is whoâs driving and whoâs riding passenger?&nbsp Part of the BRIO railway system: Featuring iconic BRIO magnetic connections, this colourful train is ready to connect to other BRIO railway vehicles and wagons.&nbsp 32260 Donald & Daisy Duck Train includes 4 pieces: 1x Donald Duck Figure, 1x Daisy Duck Figure, 1x Steam Engine, 1x Travel Wagon.</p>, Class Prediction: OTHER
# Data: <p>A living world full of surprises, secrets and danger awaits in The Survivalists, an adventure-filled, survival sandbox set in The Escapists universe.</p>
# <p>Explore, build, craft and even train monkeys with up to three friends in a desperate bid to survive. Have you got what it takes to be a Survivalist?</p>
# <p><strong>A World of Adventure and Possibilities</strong></p>
# <p>The island is alive! Your newfound home will change with day/night cycles as you explore and uncover its secrets. Hunt (or be hunted by!) animals for food and meet the local inhabitants, who arenât necessarily pleased to see you. Get quests from a Mysterious Stranger or find them washed up on the shore. Prepare to trek into a procedurally generated wilderness, with a variety of biomes, for an adventure thatâs unique to every player.&nbsp</p>
# <p><strong>Build Together, Survive Together</strong></p>
# <p>Finding the perils of island life too much or are you just looking to share your building expertise with friends? The Survivalists has you covered! Complete joint adventures, gain loot, trade and ultimately survive together and as you and up to three fellow castaways explore an island paradise.</p>
# <p><strong>Monkey See, Monkey Do!</strong></p>
# <p>If youâre in need of a builder, a lumberjack or even a soldier, the monkeys on the island can be tamed and trained to help you with everyday tasks or back you up on raids to a fanatic camp! The Mimic System means a wide variety of functions can be performed by your banana loving friends, with monkey management becoming key to surviving the islandâs challenges.&nbsp</p>
# <p><strong>Get Crafty&nbsp</strong></p>
# <p>The secret to survival is to make the most of the resources around you. Whether thatâs piecing together a primitive axe to chop wood or mixing up a refreshing fruit smoothie to keep the hunger at bay, you can discover recipes and expand your options across food, item or structure crafting trees.&nbsp</p>
# <p><strong>Run the Gauntlet</strong></p>
# <p>Looking for an epic sword to hang on your hut wall or want to lay waste to encroaching hostiles? What you seek could be in one of the many temples scattered around the island. However, getting your hands on the loot wonât be easy so any would-be raiders will need to prepare for their treasure hunting crusade.&nbsp</p>, Class Prediction: OTHER
# Data: <p>The castle shape has candy floss pink turrets and lots of hiding areas, perfect for hide and seek. Whoosh down the slide, touch the clouds on the swing or have a go on the seesaw â just add the flower wheels to the bench to convert it.&nbsp</p><p>Size:&nbsp26 x 25 x 20 cm</p>
# <p><p>Sylvanian Families evergreen toy appeals to young children just making their first friends and older children about to start secondary school. Grow your Sylvanian Village and create your own unique Sylvanian World as your collection expands.</p><p>Sylvanian Families let children craft their own stories, and helps them develop social skills and emotional intelligence through imaginative play. Sylvania is a sanctuary where everyone can be part of the family, letting children learn about relationships, including being kind to each other.</p></p>, Class Prediction: OTHER
# Data: <p><strong>Treat yourself or someone you love to this lovely gift set with perfume and body lotion from Ralph Lauren.</strong></p><p>The Ralph Lauren Woman Gift Set is a fantastic gift box for the modern woman that exudes elegance and balance. The box contains the fantastic scent in two sizes - one is perfect to keep on the bathroom shelf, where the other has a super good size for the bag, so you can always freshen up your scent. A body lotion with the same scent is also included.</p><p><strong>The set contains:</strong></p><ul><li><p>Ralph Lauren Woman EDP 50 ml</p></li><li><p>Ralph Lauren Woman EDP 10 ml</p></li><li><p>Ralph Lauren Woman Perfumed Body Lotion 75 ml</p></li></ul>, Class Prediction: OTHER
# Data: <p>Aquaman - 4K Blu ray</p>, Class Prediction: PROD_NAME
# Data: <p>Super great face and body highlighter that gives a dewy glow all year round. The light liquid highlighter is designed with ultra-fine mother-of-pearl effect that captures, reflects and refracts natural light, giving a fantastic result. It puts a translucent veil on the skin, giving body and face a beautiful glow that radiates in many facets. The highlighter from NYX Professional Makeup is available in several shades that can give exactly the look you want. All the colors each give their spectacular and amazing result.<br></p><p><strong>Application</strong>:</p>
# <ul><li>Can be used alone or mixed with foundation</li><li>Apply on cheekbones, forehead arch, bridge of the nose or wherever you want to add a radiant glow</li></ul>
# <p><b>Benefits</b>:</p><ul><li>Great face and body highlighter from NYX Professional Makeup</li><li>Gives a dewy glow all year round</li><li>Liquid</li><li>Captures, reflects and refracts natural light</li><li>Puts a translucent veil</li><li>Gives a beautiful shine</li><li>Available in several shades</li></ul>
# <p><p><strong>NYX Professional Makeup</strong></p>
# <p>NYX Professional Makeup is known for high quality and professional makeup at affordable prices
# </p>
# <p>NYX Professional Makeup is a leading brand in Color Cosmetics and is also known for their color and pigment rich products. The brand includes several series and collections of classic, seasonal and on-trend cosmetics. NYX Professional Makeup is a must-have for professional makeup artists and anyone else who loves beauty and cosmetics. The mission of the brand is to open up play, exploration and creativity with makeup - and then it must be possible to find exactly the color you want.</p></p>, Class Prediction: OTHER
# Data: <p>
# 	Fineliner with super fine metal-clad clip. Ergonomic triangular barrel for fatigue-free working. Dry-safe can be left uncapped up to 2 days without drying up. Ventilated caps in accordance with ISO 11540. Barrel and cap made from PP for long service life and low environmental impact. Water-based ink. No toxic heavy metals such as cadmium or lead-based colouring agents are used for the colouring of plastic. STAEDTLER does not use xylene and toluene as ink ingredients. Dry Safe ink increases product life span. Environmentally friendly manufacturing process. 0.8 tip gives line width of 0.3 mm.
# </p><p>
# 	<p>The name Staedtler has always been synonymous with innovation 'Made in Germany' and this can be seen directly reflected in user benefits. Over the years, we have repeatedly succeeded in developing inspirational, innovative products, which is why, when it comes to writing instruments, Staedtler is the user's clear favourite.</p>
# <p>Staedtler sees its products as helpful tools for promoting the flow of creative thoughts, coupled with the exceptional writing comfort and innovative product features that are sure to make a STAEDTLER your favourite writing instrument.</p><p>Staedtler&nbspbases its approach on the principles of European environment policy and the energy policy of the German Federal Government. In addition to conserving resources, ensuring the most efficient use of them and sustainable development, the company is committed to safeguarding biodiversity. This is also evident when it comes to products: sustainably sourced wood is the basis of our Staedtler&nbsp wood cased pencils.</p><p>Staedtler&nbsp sets especially high standards when it comes to the sourcing and processing of wood, which is one of the most important raw materials in the production of wood-cased pencils: That is why Staedtler&nbsp Mars GmbH & Co.KG is certified in line with the applicable FSC<sup>TM</sup>&nbspand PEFC standards in terms of the production and sale of wood-cased pencils. In this way, Staedtler&nbsp ensures the documentation and improvement of sustainable forestry management in relation to economic, environmental and social standards. All wood-cased Staedtler&nbsp pencils are made using certified wood.&nbspStaedtler&nbsp thus underscores its commitment to the environment and its sense of responsibility in respect of wood â an essential&nbspraw material.<br><br><br><br></p>
# </p>, Class Prediction: OTHER
# Data: <p>
# 	The son of the Greek Gods Zeus and Hera is stripped of his immortality as an infant and must become a true hero in order to reclaim it.
# </p>, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER']
# predicted class: OTHER
# number of classifications: 13
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 13 of 15 predictions.
# Original Class: description
# ________________________________________________
# ----------Dataset Mapping Summary----------
# Correctly mapped columns: 11/18
# Correctly mapped column percentage: 61.111111111111114
# map list: [['id', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM'], ['title', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME'], ['category', 'OTHER', 'PROD_NAME', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER'], ['Pris', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['ean', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM'], ['image', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['stock', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM'], ['brand', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NAME', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM'], ['weight_g', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['length_mm', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER'], ['width_mm', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['height_mm', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['hs_code', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['country_of_origin', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['Color', 'OTHER', 'PROD_NAME', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NAME', 'PROD_NAME', 'OTHER'], ['Primary Color', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER'], ['Region', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['description', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER']]
# predictions only: [['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM'], ['PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME'], ['OTHER', 'PROD_NAME', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER'], ['PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM'], ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM'], ['PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NAME', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM'], ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER'], ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM'], ['OTHER', 'PROD_NAME', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NAME', 'PROD_NAME', 'OTHER'], ['PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER'], ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER'], ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER']]
# manual map: ['PROD_NUM', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_BARCODE_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER']
# Predictions: ['PROD_NUM', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', ['PROD_NUM', 'OTHER', 'PROD_NAME'], 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER']
# Certainties: [100, 100, 100, 100, 100, 100, 100, [46.666666666666664, 46.666666666666664, 6.666666666666667], 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]
# ________________________________________________________________________
# ----------A_Discount_Market_bigbuy_da.csv----------
# ----------Mapping column 1 of 6----------
# Data: F1505132, Class Prediction: PROD_NUM
# Data: H2500221, Class Prediction: PROD_NUM
# Data: H4502023, Class Prediction: PROD_NUM
# Data: B1015101, Class Prediction: PROD_NUM
# Data: I2500274, Class Prediction: PROD_NUM
# Data: V0200127, Class Prediction: PROD_NUM
# Data: B1020182, Class Prediction: PROD_NUM
# Data: H4530117, Class Prediction: PROD_NUM
# Data: E1005102, Class Prediction: PROD_NUM
# Data: F1510295, Class Prediction: PROD_NUM
# Data: H4530150, Class Prediction: PROD_NUM
# Data: D3000212, Class Prediction: PROD_NUM
# Data: V0200182, Class Prediction: PROD_NUM
# Data: G0500148, Class Prediction: PROD_NUM
# Data: V0200264, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 15
# actual class: PROD_NUM
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 15 of 15 predictions.
# Original Class: CÃġdigo
# ________________________________________________
# ----------Mapping column 2 of 6----------
# Data: Sundhed SkÃẁnhed > Afslapning & Komfort > Puder, Class Prediction: PROD_NAME
# Data: Originale Gaver > Fest, Class Prediction: OTHER
# Data: Originale Gaver > LegetÃẁj & Spil > Licenser, Class Prediction: OTHER
# Data: KÃẁkken Gourmet > KÃẁkkenudstyr > Gryder, Class Prediction: PROD_NUM
# Data: Elektronik Computere > Ure, Class Prediction: PROD_NUM
# Data: KÃẁkken Gourmet > KÃẁkkenudstyr > Andre, Class Prediction: OTHER
# Data: KÃẁkken Gourmet > KÃẁkkenudstyr > Andre, Class Prediction: OTHER
# Data: Originale Gaver > LegetÃẁj & Spil > Andre, Class Prediction: OTHER
# Data: Parfumer Personlig pleje > Til Kvinder > Kosmetik til kvinder, Class Prediction: OTHER
# Data: Sundhed SkÃẁnhed > Afslapning & Komfort > TÃḊpper med Ãrmer, Class Prediction: PROD_NUM
# Data: Originale Gaver > LegetÃẁj & Spil > Andre, Class Prediction: OTHER
# Data: Husholdning RengÃẁring > Belysning, Class Prediction: PROD_NAME

# %%
print('EVAL', eval_list)
print('OVERALL', percent_list)
average_total_autoperf = statistics.mean(percent_list)
print('Average automation percentage:', average_total_autoperf)
