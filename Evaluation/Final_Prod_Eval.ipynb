# %%
import re
import os
import pickle
import keras
import statistics

import numpy as np
import pandas as pd

from os import listdir
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing import sequence

EAN_REGEX = '(?<=\s)\d{13}(?=\s)'
MODEL_DIR = \
    r'C:\Users\mail\PycharmProjects\MLDM\Data\Final\NAME_NUM_OTHER_Oversampled\models\NAME_NUM_OTHER_OVER_WORDEMB.h5'
TOKENIZER_DIR =\
    r'C:\Users\mail\PycharmProjects\MLDM\Data\Final\NAME_NUM_OTHER_Oversampled\models\NAME_NUM_OTHER_OVER_WORDEMB.pkl'

THRESHOLD = 0.51
SAMPLE_AMOUNT = 100
RANDOM_STATE = 7
TARGETS = ['PROD_NAME', 'PROD_NUM', 'OTHER']
model = keras.models.load_model(MODEL_DIR)
tokenizer = pickle.load(open(TOKENIZER_DIR, 'rb'))
le = LabelEncoder()
print('Model, Tokenizer and LabelEncoder loaded.')

def predictClass(text, tok, model):
    text_pad = sequence.pad_sequences(tok.texts_to_sequences([text]), maxlen=300)
    predict_x = model.predict(text_pad)
    predict_class = np.argmax(predict_x, axis=1)
    score = le.inverse_transform(predict_class)
    prediction = score[0]
    return prediction

PATH = r'C:\Users\mail\Downloads\data\Eval Datasets'
list_files = listdir(PATH)
k = 0
eval_list = []
percent_list = []
percent_list_known = []


def evaluate(num):
    correct = 0
    dataset_filename = os.listdir(PATH)[num]
    print('________________________________________________________________________')
    print('----------{}----------'.format(dataset_filename))
    dataset_path = os.path.join("../..", PATH, dataset_filename)
    df = pd.read_csv(dataset_path, error_bad_lines=False, engine='c',
                 encoding='ISO-8859-14', low_memory=False, dtype=str)
    if len(df.index) >= SAMPLE_AMOUNT:
        try:
            df = df.sample(SAMPLE_AMOUNT,
                           random_state=RANDOM_STATE)
        except ValueError:
            pass
    df = df.reset_index(drop=True)
    column_headers = list(df.columns)
    # list of list of predictions including original column name
    predictions_map = list(map(lambda item: [item], column_headers))

    # list of list of predictions only - populate now then popped later
    predictions_only = list(map(lambda item: [item], column_headers))

    map_list = []
    maps_object = []
    Predictions = []
    Certainty = []
    manual_maps_list = []

    for n in range(len(column_headers)):
        print('----------Mapping column {num} of {len}----------'
              .format(num=n+1, len=len(column_headers)))
        df_select = df[column_headers[n]]
        # sequence padding and tokenization of data requires string type
        df_select = df_select.astype(str)
        multiple_predictions = []
        multiple_certainties = []

        for m in range(len(df_select)):
            class_predictions =[]
            targets = TARGETS
            targets = le.fit_transform(targets)
            data = df_select[m]
            if re.search(EAN_REGEX, data):
                predicted_class = 'PROD_BARCODE_NUM'
            elif len(data) > 200 or np.isnan(data):
                predicted_class = 'OTHER'
            else:
                predicted_class = predictClass(data, tokenizer, model)
            predictions_map[n].append(predicted_class)
            predictions_only[n].append(predicted_class)
            print('Data: {data}, Class Prediction: {prediction}'
                  .format(data=data, prediction=predicted_class))

        predictions_only[n].pop(0)
        column_predictions = (predictions_only[n])
        column_predictions_series = pd.Series(column_predictions)
        column_predictions_count = column_predictions_series.value_counts()
        print('----------Column Mapping Summary----------')
        print('column predictions:', column_predictions)
        #print('column predictions series:', column_predictions_series)
        #print('column predictions count:', column_predictions_count)
        print('predicted class:', column_predictions_count.index[0])
        print('number of classifications:', column_predictions_count.iloc[0])
        print('actual class:', manual_maps[num][n])

        if column_predictions_count.iloc[0] > len(df_select) * THRESHOLD:
            print(column_predictions_count.index[0], 'is the Majority Predicted Class.')
            print('The majority class is: {pred}; {num_pred} of {len} predictions.'
                  '\nOriginal Class: {origin}'
                  .format(pred=column_predictions_count.index[0],
                          num_pred=column_predictions_count.iloc[0],
                          len=len(df_select),
                          origin=column_headers[n]))
            Predictions.append(column_predictions_count.index[0])
            Certainty.append(100)

        else:
            print('There is no Majority Predicted Class above the threshold.'
                  '\nOriginal Class: {origin}'
                  .format(origin=column_headers[n]))
            for i in range(len(column_predictions_count)):
                print('Predicted class {i}: {pred}; {num_pred} of {len} predictions.'
                      .format(i=i+1,
                              pred=column_predictions_count.index[i],
                              num_pred=column_predictions_count.iloc[i],
                              len=len(df_select)))
                multiple_predictions.append(column_predictions_count.index[i])
                multiple_certainties.append(column_predictions_count.iloc[i] / len(df_select) * 100)
            Predictions.append(multiple_predictions)
            Certainty.append(multiple_certainties)
        if column_predictions_count.index[0] == manual_maps[num][n]:
                correct +=1
        print('________________________________________________')

    print('----------Dataset Mapping Summary----------')
    percent = correct/len(column_headers)*100
    print('Correctly mapped columns: {correct}/{total}'.format(correct=correct, total=len(column_headers)))
    print('Correctly mapped column percentage: {percent}'.format(percent=percent))
    percent_list.append(percent)
    print('map list:', predictions_map)
    print('predictions only:', predictions_only)
    for item in range(len(manual_maps[num])):
        temp = manual_maps[num][item]
        manual_maps_list.append(temp)
    print('manual map:', manual_maps_list)
    print('Predictions:', Predictions)
    print('Certainties:', Certainty)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model, Tokenizer and LabelEncoder loaded.

# %%
manual_map_A_dataset = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'PROD_BARCODE_NUM', 5: 'OTHER',
                        6: 'OTHER', 7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12 : 'OTHER',
                        13: 'OTHER', 14: 'OTHER', 15: 'OTHER', 16: 'OTHER', 17: 'OTHER'}
manual_map_A_Discount_bigbuy_da = {0: 'PROD_NUM', 1: 'OTHER', 2: 'PROD_NAME', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER'}
manual_map_A_Discount_bigbuy_en = {0: 'PROD_NUM', 1: 'OTHER', 2: 'PROD_NAME', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER'}
manual_map_A_Discount_Compressed1 = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'PROD_BARCODE_NUM', 4: 'OTHER',
                                     5: 'OTHER'}
manual_map_A_Discount_Compressed2 = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'PROD_BARCODE_NUM', 4:'OTHER'}
manual_map_A_Discount_presta_product_2399_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER', 6: 'OTHER'}
manual_map_A_Discount_presta_product_2403_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'OTHER'}
manual_map_A_Discount_presta_product_2507_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5:
    'PROD_BARCODE_NUM', 6: 'OTHER', 7: 'OTHER'}
manual_map_A_Discount_presta_product_2507_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'PROD_BARCODE_NUM', 6: 'OTHER', 7: 'OTHER'}
manual_map_A_Discount_presta_product_2570_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'PROD_BARCODE_NUM'}
manual_map_A_Discount_presta_product_2570_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'PROD_BARCODE_NUM'}
manual_map_A_Discount_presta_product_2662_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER'}
manual_map_A_Discount_presta_product_2662_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER', 6: 'OTHER'}
manual_map_A_Discount_presta_product_2678_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER'}
manual_map_A_Discount_presta_product_2678_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER',
                                                4: 'PROD_BARCODE_NUM', 5: 'OTHER', 6: 'OTHER'}
manual_map_A_Discount_presta_product_3046_da = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'OTHER', 6: 'PROD_BARCODE_NUM', 7: 'OTHER', 8: 'OTHER'}
manual_map_A_Discount_presta_product_3046_en = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER',
                                                5: 'OTHER', 6: 'PROD_BARCODE_NUM', 7: 'OTHER', 8: 'OTHER'}
manual_map_Bisgaard = {0: 'PROD_BARCODE_NUM', 1: 'OTHER', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER', 7: 'OTHER',
             8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER', 13: 'OTHER', 14: 'OTHER', 15: 'OTHER',
            16: 'OTHER', 17: 'OTHER', 18: 'OTHER', 19: 'OTHER', 20: 'OTHER', 21: 'OTHER', 22: 'OTHER', 23: 'OTHER',
            24: 'OTHER'}
manual_map_Scand = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'PROD_BARCODE_NUM', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                    7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER'}
manual_map_items = {0: 'PROD_NUM', 1: 'PROD_BARCODE_NUM', 2:'PROD_NAME', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                    7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER'}
manual_map_Joha = {0: 'OTHER', 1: 'OTHER', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5: 'PROD_BARCODE_NUM', 6: 'OTHER',
                   7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER', 13: 'OTHER', 14: 'OTHER',
                   15: 'OTHER', 16: 'OTHER' }
manual_map_Modern_classic_upstart = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'PROD_BARCODE_NUM', 3: 'OTHER', 4: 'OTHER',
                                     5: 'OTHER', 6: 'OTHER', 7: 'OTHER'}
manual_map_PIF = {0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'PROD_BARCODE_NUM', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                  7: 'OTHER'}
manual_map_prisliste ={0: 'PROD_NUM', 1: 'PROD_NAME', 2: 'OTHER', 3: 'OTHER', 4: 'OTHER', 5: 'OTHER', 6: 'OTHER',
                       7: 'OTHER', 8: 'OTHER', 9: 'OTHER', 10: 'OTHER', 11: 'OTHER', 12: 'OTHER', 13: 'OTHER',
                       14:'OTHER', 15: 'OTHER', 16: 'OTHER', 17: 'PROD_BARCODE_NUM', 18: 'OTHER'}
manual_map_VAREFIL = {0: 'PROD_NUM', 1: 'PROD_BARCODE_NUM', 2: 'PROD_NAME', 3: 'PROD_NAME', 4: 'OTHER',  5: 'OTHER',
                      6: 'OTHER'}

manual_maps = [manual_map_A_dataset, manual_map_A_Discount_bigbuy_da, manual_map_A_Discount_bigbuy_en,
               manual_map_A_Discount_Compressed1, manual_map_A_Discount_Compressed2, manual_map_A_Discount_presta_product_2399_da,
               manual_map_A_Discount_presta_product_2403_en, manual_map_A_Discount_presta_product_2507_da,
               manual_map_A_Discount_presta_product_2507_en, manual_map_A_Discount_presta_product_2570_da,
               manual_map_A_Discount_presta_product_2570_en, manual_map_A_Discount_presta_product_2662_da,
               manual_map_A_Discount_presta_product_2662_en, manual_map_A_Discount_presta_product_2678_da,
               manual_map_A_Discount_presta_product_2678_en, manual_map_A_Discount_presta_product_3046_da,
               manual_map_A_Discount_presta_product_3046_en, manual_map_Bisgaard, manual_map_Scand, manual_map_items,
              manual_map_Joha, manual_map_Modern_classic_upstart, manual_map_PIF, manual_map_prisliste, manual_map_VAREFIL]

# %%
for i in range(len(list_files)):
    evaluate(i)
#evaluate(0)
#evaluate(1)
# Out:
# ________________________________________________________________________
# ----------A_dataset.csv----------
# ----------Mapping column 1 of 18----------
# Data: 235F6X, Class Prediction: PROD_NUM
# Data: 2384TB, Class Prediction: PROD_NUM
# Data: 238EB5, Class Prediction: PROD_NUM
# Data: AJ6TU2, Class Prediction: PROD_NUM
# Data: 234DW8, Class Prediction: PROD_NUM
# Data: 2394EG, Class Prediction: PROD_NUM
# Data: 235PC7, Class Prediction: PROD_NUM
# Data: 237GB4, Class Prediction: PROD_NUM
# Data: 235AQ7, Class Prediction: PROD_NUM
# Data: AM32GN, Class Prediction: PROD_NUM
# Data: 237V58, Class Prediction: PROD_NUM
# Data: AG7Z9K, Class Prediction: PROD_NUM
# Data: 235T7E, Class Prediction: PROD_NUM
# Data: AN637D, Class Prediction: PROD_NUM
# Data: AD8V6Q, Class Prediction: PROD_NUM
# Data: AK593Y, Class Prediction: PROD_NUM
# Data: AR83SE, Class Prediction: PROD_NUM
# Data: 235KD7, Class Prediction: PROD_NUM
# Data: AM8K3N, Class Prediction: PROD_NUM
# Data: AK642J, Class Prediction: PROD_NUM
# Data: 237J4K, Class Prediction: PROD_NUM
# Data: AK36ZH, Class Prediction: PROD_NUM
# Data: 237M4G, Class Prediction: PROD_NUM
# Data: 235YT6, Class Prediction: PROD_NUM
# Data: 238E6T, Class Prediction: PROD_NUM
# Data: AJ46P7, Class Prediction: PROD_NUM
# Data: 234QK8, Class Prediction: PROD_NUM
# Data: AD5K9S, Class Prediction: PROD_NUM
# Data: 235F4N, Class Prediction: PROD_NUM
# Data: 235U97, Class Prediction: PROD_NUM
# Data: 23547B, Class Prediction: PROD_NUM
# Data: 2345HR, Class Prediction: PROD_NUM
# Data: 2357H9, Class Prediction: PROD_NUM
# Data: AE8KB6, Class Prediction: PROD_NUM
# Data: 2347W9, Class Prediction: PROD_NUM
# Data: 238B76, Class Prediction: PROD_NUM
# Data: AD4C7H, Class Prediction: PROD_NUM
# Data: A3SB6N, Class Prediction: PROD_NUM
# Data: 234K7Y, Class Prediction: PROD_NUM
# Data: 234PC9, Class Prediction: PROD_NUM
# Data: 234WY8, Class Prediction: PROD_NUM
# Data: AJ25RX, Class Prediction: PROD_NUM
# Data: 238E5F, Class Prediction: PROD_NUM
# Data: 2346Y9, Class Prediction: PROD_NUM
# Data: 2376KM, Class Prediction: PROD_NUM
# Data: 236KX8, Class Prediction: PROD_NUM
# Data: AF89VB, Class Prediction: PROD_NUM
# Data: 236W4N, Class Prediction: PROD_NUM
# Data: AM7JX6, Class Prediction: PROD_NUM
# Data: 2395PJ, Class Prediction: PROD_NUM
# Data: 238GY4, Class Prediction: PROD_NUM
# Data: 238C7E, Class Prediction: PROD_NUM
# Data: 2375AM, Class Prediction: PROD_NUM
# Data: 235HS6, Class Prediction: PROD_NUM
# Data: AM78QP, Class Prediction: PROD_NUM
# Data: 2389QE, Class Prediction: PROD_NUM
# Data: AC82TH, Class Prediction: PROD_NUM
# Data: 235PW7, Class Prediction: PROD_NUM
# Data: 234VJ5, Class Prediction: PROD_NUM
# Data: AE249C, Class Prediction: PROD_NUM
# Data: 2379MB, Class Prediction: PROD_NUM
# Data: AM3R8V, Class Prediction: PROD_NUM
# Data: 238Z7R, Class Prediction: PROD_NUM
# Data: 2374AP, Class Prediction: PROD_NUM
# Data: 237C86, Class Prediction: PROD_NUM
# Data: AB5DN6, Class Prediction: PROD_NUM
# Data: 2385ZQ, Class Prediction: PROD_NUM
# Data: AH364K, Class Prediction: PROD_NUM
# Data: 2385X7, Class Prediction: PROD_NUM
# Data: 2385CU, Class Prediction: PROD_NUM
# Data: 234R9X, Class Prediction: PROD_NUM
# Data: AB8R4G, Class Prediction: PROD_NUM
# Data: 237Z6B, Class Prediction: PROD_NUM
# Data: AB5EM7, Class Prediction: PROD_NUM
# Data: 234H5T, Class Prediction: PROD_NUM
# Data: 2394SN, Class Prediction: PROD_NUM
# Data: AG9S6R, Class Prediction: PROD_NUM
# Data: 236R4V, Class Prediction: PROD_NUM
# Data: 237VJ5, Class Prediction: PROD_NUM
# Data: AK46D3, Class Prediction: PROD_NUM
# Data: 2374GY, Class Prediction: PROD_NUM
# Data: AC3TU2, Class Prediction: PROD_NUM
# Data: 2394GN, Class Prediction: PROD_NUM
# Data: 2347XS, Class Prediction: PROD_NUM
# Data: AF5RS9, Class Prediction: PROD_NUM
# Data: AB3H2M, Class Prediction: PROD_NUM
# Data: 236Q7A, Class Prediction: PROD_NUM
# Data: 23765Y, Class Prediction: PROD_NUM
# Data: 237B5N, Class Prediction: PROD_NUM
# Data: AB49M5, Class Prediction: PROD_NUM
# Data: 2374KV, Class Prediction: PROD_NUM
# Data: 234X7B, Class Prediction: PROD_NUM
# Data: AJ7RP4, Class Prediction: PROD_NUM
# Data: 237K84, Class Prediction: PROD_NUM
# Data: AC9F7P, Class Prediction: PROD_NUM
# Data: AH26B8, Class Prediction: PROD_NUM
# Data: 234NA8, Class Prediction: PROD_NUM
# Data: 238WU9, Class Prediction: PROD_NUM
# Data: AH7492, Class Prediction: PROD_NUM
# Data: 235K7Y, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM']
# predicted class: PROD_NUM
# number of classifications: 100
# actual class: PROD_NUM
# PROD_NUM is the Majority Predicted Class.
# The majority class is: PROD_NUM; 100 of 100 predictions.
# Original Class: id
# ________________________________________________
# ----------Mapping column 2 of 18----------
# Data: StreetSurfing - Ripper HIC Løbehjul - Rød, Class Prediction: PROD_NUM
# Data: X-Shot - Dino Attack Dino Striker Foam Dart Blaster, Class Prediction: PROD_NAME
# Data: LEGO DOTS - Kreativt designersÃḊt (41938), Class Prediction: PROD_NAME
# Data: Rødtotterne og Tyrannos - DVD, Class Prediction: PROD_NAME
# Data: Essie - Spring 2020 Neglelak - 684 Feeling Wellies, Class Prediction: PROD_NAME
# Data: BEN 10 - Heroes & Villains - Diamondhead, Class Prediction: PROD_NAME
# Data: Prinsesse Sissi 1- DVD, Class Prediction: PROD_NAME
# Data: BRIO - Anders og Andersine-tog (32260), Class Prediction: PROD_NAME
# Data: The Survivalists, Class Prediction: PROD_NAME
# Data: Sylvanian Families - Baby Slotsbørnehave (5316), Class Prediction: PROD_NAME
# Data: Ralph Lauren - Woman EDP 50 ml + Body Lotion 75 ml + Rollerball 10 ml GavesÃḊt, Class Prediction: PROD_NAME
# Data: Aquaman - 4K Blu ray, Class Prediction: PROD_NAME
# Data: NYX Professional Makeup - California Beamin' Ansigt & Krop Flydende Highlighter - Golden Glow, Class Prediction: PROD_NAME
# Data: Staedtler - Triplus Fineliner, 30 stk (334 C30P), Class Prediction: PROD_NAME
# Data: Disneys Hercules (Blu-Ray), Class Prediction: PROD_NAME
# Data: Thor 3: Ragnarok - DVD, Class Prediction: PROD_NAME
# Data: MX vs ATV Reflex, Class Prediction: PROD_NAME
# Data: Create Your - Eventyrlig KlistermÃḊrke Bog, Class Prediction: PROD_NAME
# Data: Astralis Merc Official T-Shirt SS 2019 - M, Class Prediction: PROD_NAME
# Data: Bjørne Brødre Disney classic#43, Class Prediction: PROD_NAME
# Data: Paco Rabanne - Invictus Victory EDP 100 ml, Class Prediction: PROD_NAME
# Data: Sudden Strike 4: European Battlefields Edition, Class Prediction: PROD_NAME
# Data: On Golden Pond, Class Prediction: PROD_NAME
# Data: BABY Born - Hundelufter, 43cm, Class Prediction: PROD_NAME
# Data: LEGO Friends - Skov-autocamper og sejlbåd (41681), Class Prediction: PROD_NAME
# Data: Billet mrk., Class Prediction: PROD_NUM
# Data: Sparkle Girlz - Little Friends SÃḊt med 10 Dukker, Class Prediction: PROD_NAME
# Data: Apocalypse WWI -DVD, Class Prediction: PROD_NUM
# Data: Lord of the Rings Mini Epics - Frodo Baggins, Class Prediction: PROD_NAME
# Data: Ty Bamse - Beanie Boos - Pandaen Paris (Medium), Class Prediction: PROD_NAME
# Data: Diesel - Loverdose Red Kiss EDP 50 ml, Class Prediction: PROD_NAME
# Data: Playfun - Sjippetov m/lilla håndtag, Class Prediction: PROD_NAME
# Data: PLAY - Gå på Opdagelse i Haven, Class Prediction: PROD_NAME
# Data: Brand-Børge rykker ud - DVD, Class Prediction: PROD_NAME
# Data: LEGO City - Monstertruck-kup (60245), Class Prediction: PROD_NAME
# Data: Call of Duty Ghosts - Free Fall Limited Edition, Class Prediction: PROD_NAME
# Data: Baja Edge of Control HD, Class Prediction: PROD_NAME
# Data: Kevin Murphy - Easy.Rider 110 ml, Class Prediction: PROD_NAME
# Data: House Doctor - Hapur Stol - Natur, Class Prediction: PROD_NAME
# Data: Palle Alene I Verden, Class Prediction: PROD_NAME
# Data: Happy People - Scout - LydforstÃḊrker, Class Prediction: PROD_NAME
# Data: Madagascar 3: Europe's Most Wanted (Blu-Ray), Class Prediction: PROD_NAME
# Data: LEGO Friends - Mias fodboldboks (41669), Class Prediction: PROD_NAME
# Data: Vejrhanen, Class Prediction: PROD_NUM
# Data: Top Model - Fantasy Model - XXL Penalhus - Fairy, Class Prediction: PROD_NAME
# Data: Psychobitch, Class Prediction: PROD_NUM
# Data: Dr. Hauschka - Foundation - 02 Almond, Class Prediction: PROD_NAME
# Data: Dungeons & Dragons - 5th Ed. Tasha's Cauldron O Everything (D&D) (WTCC7878), Class Prediction: PROD_NAME
# Data: Spar Es - Flaske Oplukker, Class Prediction: PROD_NAME
# Data: Ciao - Børnekostume - Sort Ninja Deluxe SÃḊt (10-12 år), Class Prediction: PROD_NAME
# Data: Celtic - BrÃḊtspil (Nordisk+Engelsk) (LPFI7507), Class Prediction: PROD_NAME
# Data: Rice - Small Square Raffia Basket with Leather Handles - Green, Class Prediction: PROD_NAME
# Data: Babyliss - Airstyler Shape & Smooth Varmluft krøllejern  AS82E, Class Prediction: PROD_NAME
# Data: Playmobil - Rideundervisning i hestestalden (70450), Class Prediction: PROD_NAME
# Data: The Shining, Class Prediction: PROD_NAME
# Data: Rastar - Ferrari 488 GTB - R/C 1:14, Class Prediction: PROD_NAME
# Data: Lykketrold - Mekaniker Trold 9 cm, Class Prediction: PROD_NAME
# Data: Babytrold - Regnslag Jogger SB, Class Prediction: PROD_NAME
# Data: Barberians Copenhagen - Active Hair & Body Wash 250 ml, Class Prediction: PROD_NAME
# Data: Ultra Street Fighter 2: The Final Challengers, Class Prediction: PROD_NAME
# Data: 8bitdo Mobile Clip Pro 2, Class Prediction: PROD_NAME
# Data: Dykkerner - DVD, Class Prediction: PROD_NUM
# Data: Paco Rabanne - 1 Million EDP 80 ml + Sensual Body Lotion 100 ml - GavesÃḊt, Class Prediction: PROD_NAME
# Data: DON ONE - WBC400  4K ULTRA HD PRO Webkamera 3840 x 2160pixels, Class Prediction: PROD_NAME
# Data: RIG 700HX Ultralight Wireless Gaming Headset Black XONE/XSERESX, Class Prediction: PROD_NAME
# Data: Mysterium - Core Game (Nordic), Class Prediction: PROD_NAME
# Data: Immortal: Unchained, Class Prediction: PROD_NUM
# Data: Faber-Castell - Colour GRIP farveblyant, tinÃḊske med 36 stk (112435), Class Prediction: PROD_NAME
# Data: Kiddieland - Paw Patrol Gåbil m/Lys og Lyd, Class Prediction: PROD_NAME
# Data: Schleich - Tyrannosaurus rex, ungvoksen (15007), Class Prediction: PROD_NAME
# Data: 24 Bottles - Urban Bottle 0,5 L - Antigua, Class Prediction: PROD_NAME
# Data: Nina Ricci - Les Sorbets Bella EDT 50 ml, Class Prediction: PROD_NAME
# Data: Shin Megami Tensei III Nocturne HD Remaster, Class Prediction: PROD_NUM
# Data: Schleich - Hesteboks med araberheste og hestepasser (42369), Class Prediction: PROD_NAME
# Data: REN - Perfect Canvas Jelly Oil Cleanser 100 ml, Class Prediction: PROD_NAME
# Data: Top Model - Malebog m/Tegneredskaber, Class Prediction: PROD_NAME
# Data: WWF - Panda bamse - 23 cm, Class Prediction: PROD_NAME
# Data: Pampers - 38 Stk Premium Care Bleer Str 2, Class Prediction: PROD_NAME
# Data: Zack Snyderâs Justice League, Class Prediction: PROD_NAME
# Data: In This Corner of the World, Class Prediction: PROD_NAME
# Data: Ravensburger - Puslespil 1000 - Nyhavn, København, Class Prediction: PROD_NAME
# Data: Før Frosten - DVD, Class Prediction: PROD_NUM
# Data: âJulefeber - 4 Disc, Class Prediction: PROD_NAME
# Data: Barbie - Hus og Dukke, Class Prediction: PROD_NAME
# Data: The Crew - Wild Run edition, Class Prediction: PROD_NAME
# Data: Heartstone (Søren Malling) - DVD, Class Prediction: PROD_NUM
# Data: Gyllene Tider - Konsert 2019, Class Prediction: PROD_NAME
# Data: Save My Bones - Beskyttelses sÃḊt - Sort L, Class Prediction: PROD_NAME
# Data: Spirit: Lucky's Big Adventure, Class Prediction: PROD_NAME
# Data: Star Wars - Outer Rim - BrÃḊtspil (Engelsk), Class Prediction: PROD_NAME
# Data: LIKEconcrete - Freja Knageâ Small - Hvid, Class Prediction: PROD_NAME
# Data: Design Letters - MyCharger P - Black (60201015P), Class Prediction: PROD_NAME
# Data: Michael Jackson Treasures â Danish book, Class Prediction: PROD_NAME
# Data: Field Of Dreams, Class Prediction: PROD_NAME
# Data: Sankt Bernhard Syndikatet - DVD, Class Prediction: PROD_NUM
# Data: Switch Quad Charger Joy-Con, Class Prediction: PROD_NAME
# Data: Buddha Karaffel, Class Prediction: PROD_NUM
# Data: Wolfenstein: Youngblood (Deluxe Edition), Class Prediction: PROD_NAME
# Data: Philips Hue  - Flourish Bordlampe Bluetooth - White & Color Ambiance, Class Prediction: PROD_NAME
# Data: ReCore (UK/Arabic), Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NUM', 'PROD_NAME', 'PROD_NAME', 'PROD_NUM']
# predicted class: PROD_NAME
# number of classifications: 87
# actual class: PROD_NAME
# PROD_NAME is the Majority Predicted Class.
# The majority class is: PROD_NAME; 87 of 100 predictions.
# Original Class: title
# ________________________________________________
# ----------Mapping column 3 of 18----------
# Data: Legetøj - Løbehjul, løbecykler og vogne - Løbehjul, Class Prediction: OTHER
# Data: Legetøj - Udendørs legetøj - Blaster og skydelegetøj, Class Prediction: PROD_NAME
# Data: Legetøj - Konstruktionslegetøj - ByggesÃḊt, Class Prediction: PROD_NUM
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Skønhed - Makeup - Negle - Neglelak, Class Prediction: OTHER
# Data: Legetøj - Figurer - Superhelte, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Biler, tog og køretøjer - Tog og togbaner - Togvogne, Class Prediction: OTHER
# Data: Spil og konsoller - Nintendo Switch - Spil, Class Prediction: OTHER
# Data: Legetøj - Dukker og dukkehuse - Dukkehuse og tilbehør - Dukkehuse, Class Prediction: OTHER
# Data: Skønhed - Parfume - ParfumesÃḊt, Class Prediction: PROD_NAME
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Skønhed - Makeup - Ansigt - Contour og highlight, Class Prediction: PROD_NAME
# Data: Legetøj - Kreativt legetøj - Tusser og penne, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Spil og konsoller - PlayStation 3 - Spil, Class Prediction: OTHER
# Data: Legetøj - Kreativt legetøj - Papir og klistermÃḊrker, Class Prediction: OTHER
# Data: Tøj - Herremode - T-shirts, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Skønhed - Parfume - Eau de Parfum, Class Prediction: OTHER
# Data: Spil og konsoller - Xbox One - Spil, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Dukker og dukkehuse - Dukker og tilbehør - Dukketøj, Class Prediction: OTHER
# Data: Legetøj - Konstruktionslegetøj - ByggesÃḊt, Class Prediction: PROD_NUM
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Dukker og dukkehuse - Modedukker og tilbehør - Modedukker, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Fanshop og merchandises - Film og TV-Serier - Figurer, Class Prediction: OTHER
# Data: Legetøj - Bamser og plysdyr, Class Prediction: PROD_NAME
# Data: Skønhed - Parfume - Eau de Parfum, Class Prediction: OTHER
# Data: Legetøj - Udendørs legetøj - Sjippetov, Class Prediction: PROD_NUM
# Data: Legetøj - LÃḊrerigt legetøj - Natur og udeliv, Class Prediction: PROD_NAME
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Konstruktionslegetøj - ByggesÃḊt, Class Prediction: PROD_NUM
# Data: Spil og konsoller - PlayStation 3 - Spil, Class Prediction: OTHER
# Data: Spil og konsoller - PlayStation 4 - Spil, Class Prediction: OTHER
# Data: Skønhed - Hårpleje - Styling produkter - Styling behandling, Class Prediction: OTHER
# Data: Bolig og køkken - Møbler - Spisestue - Stole, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Rolleleg - VÃḊrktøj, Class Prediction: PROD_NUM
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Konstruktionslegetøj - ByggesÃḊt, Class Prediction: PROD_NUM
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Skole - Penalhus, Class Prediction: PROD_NAME
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Skønhed - Makeup - Ansigt - Foundation, Class Prediction: OTHER
# Data: Legetøj - BrÃḊtspil og spil - Rollespil, Class Prediction: OTHER
# Data: Gadgets - Bar og køkken, Class Prediction: OTHER
# Data: Legetøj - UdklÃḊdning, Class Prediction: PROD_NUM
# Data: Legetøj - BrÃḊtspil og spil - Strategispil, Class Prediction: OTHER
# Data: Baby og børn - Møbler - Opbevaring, Class Prediction: OTHER
# Data: Skønhed - Hårpleje - Hårtørrere, hårjern og tilbehør - Krøllejern og -stave, Class Prediction: PROD_NAME
# Data: Legetøj - Figurer - Prinsesser, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Fjernstyrede køretøjer - Fjernstyrede biler, Class Prediction: PROD_NUM
# Data: Bolig og køkken - Boligindretning - Boliginteriør, Class Prediction: PROD_NAME
# Data: Baby og børn - Klapvogne, barnevogne og tilbehør - Dele og tilbehør - Regn og vindslag, Class Prediction: OTHER
# Data: Skønhed - Bad og krop - Brusebad - Body shower, Class Prediction: OTHER
# Data: Spil og konsoller - Nintendo Switch - Spil, Class Prediction: OTHER
# Data: Elektronik - Smartphones og tablets - Tilbehør - Stativer og stande, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Skønhed - Parfume - ParfumesÃḊt, Class Prediction: PROD_NAME
# Data: Computere - Tilbehør - Webcam, Class Prediction: PROD_NAME
# Data: Elektronik - Audio og HiFi - Hovedtelefoner og headsets - Over-ear, Class Prediction: OTHER
# Data: Legetøj - BrÃḊtspil og spil - Strategispil, Class Prediction: OTHER
# Data: Spil og konsoller - PlayStation 4 - Spil, Class Prediction: OTHER
# Data: Legetøj - Kreativt legetøj - Farver og farveblyanter, Class Prediction: OTHER
# Data: Legetøj - Babylegetøj og tumling - Gåbiler, Class Prediction: OTHER
# Data: Legetøj - Figurer - Dinosaurer, Class Prediction: OTHER
# Data: Bolig og køkken - Køkken og spisestue - To-Go - Drikkeflasker, Class Prediction: OTHER
# Data: Skønhed - Parfume - Eau de Toilette, Class Prediction: PROD_NAME
# Data: Spil og konsoller - Nintendo Switch - Spil, Class Prediction: OTHER
# Data: Legetøj - Figurer - Dyr og bondegård - Bondegårde og bygninger, Class Prediction: OTHER
# Data: Skønhed - Hudpleje - Ansigt - Renseprodukter - Gele, Class Prediction: PROD_NAME
# Data: Legetøj - Kreativt legetøj - Malebøger og -blokke, Class Prediction: OTHER
# Data: Legetøj - Bamser og plysdyr, Class Prediction: PROD_NAME
# Data: Baby og børn - Barnepleje - Alt til bleer - Bleer - Engangsbleer, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Puslespil og hjernevridere - Familie puslespil - Puslespil 1000+, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Dukker og dukkehuse - Modedukker og tilbehør - Huse, Class Prediction: OTHER
# Data: Spil og konsoller - PlayStation 4 - Spil, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Legetøj - Løbehjul, løbecykler og vogne - Cykelhjelme og udstyr - BeskyttelsessÃḊt, Class Prediction: OTHER
# Data: Spil og konsoller - PlayStation 4 - Spil, Class Prediction: OTHER
# Data: Legetøj - BrÃḊtspil og spil - Strategispil, Class Prediction: OTHER
# Data: Bolig og køkken - Opbevaring - Kroge, Class Prediction: OTHER
# Data: Elektronik - Smartphones og tablets - Tilbehør - Opladere - Mobile powerbanks, Class Prediction: OTHER
# Data: Musik - CD, Class Prediction: PROD_NAME
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Film og TV-serier - Film, Class Prediction: OTHER
# Data: Spil og konsoller - Nintendo Switch - Tilbehør - Opladere, Class Prediction: OTHER
# Data: Gadgets - Bar og køkken, Class Prediction: OTHER
# Data: Spil og konsoller - PlayStation 4 - Spil, Class Prediction: OTHER
# Data: Bolig og køkken - Belysning - Bordlamper, Class Prediction: OTHER
# Data: Spil og konsoller - Xbox One - Spil, Class Prediction: OTHER
# ----------Column Mapping Summary----------
# column predictions: ['OTHER', 'PROD_NAME', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'PROD_NUM', 'PROD_NAME', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NAME', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER']
# predicted class: OTHER
# number of classifications: 78
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 78 of 100 predictions.
# Original Class: category
# ________________________________________________
# ----------Mapping column 4 of 18----------
# Data: 569, Class Prediction: PROD_NUM
# Data: 99, Class Prediction: OTHER
# Data: 206, Class Prediction: PROD_NUM
# Data: 18, Class Prediction: OTHER
# Data: 59, Class Prediction: PROD_NUM
# Data: 49, Class Prediction: PROD_NUM
# Data: 55, Class Prediction: OTHER
# Data: 99, Class Prediction: OTHER
# Data: 159, Class Prediction: OTHER
# Data: 199, Class Prediction: PROD_NUM
# Data: 349, Class Prediction: PROD_NUM
# Data: 140, Class Prediction: OTHER
# Data: 60, Class Prediction: OTHER
# Data: 129, Class Prediction: OTHER
# Data: 60, Class Prediction: OTHER
# Data: 57, Class Prediction: OTHER
# Data: 85, Class Prediction: OTHER
# Data: 43, Class Prediction: PROD_NUM
# Data: 199, Class Prediction: PROD_NUM
# Data: 60, Class Prediction: OTHER
# Data: 499, Class Prediction: OTHER
# Data: 59, Class Prediction: PROD_NUM
# Data: 30, Class Prediction: OTHER
# Data: 149, Class Prediction: OTHER
# Data: 270, Class Prediction: PROD_NUM
# Data: 35, Class Prediction: PROD_NUM
# Data: 119, Class Prediction: PROD_NUM
# Data: 38, Class Prediction: OTHER
# Data: 165, Class Prediction: OTHER
# Data: 55, Class Prediction: OTHER
# Data: 229, Class Prediction: OTHER
# Data: 19, Class Prediction: PROD_NUM
# Data: 239, Class Prediction: PROD_NUM
# Data: 28, Class Prediction: OTHER
# Data: 256, Class Prediction: PROD_NUM
# Data: 29, Class Prediction: OTHER
# Data: 75, Class Prediction: OTHER
# Data: 169, Class Prediction: PROD_NUM
# Data: 623.2, Class Prediction: OTHER
# Data: 30, Class Prediction: OTHER
# Data: 149, Class Prediction: OTHER
# Data: 14, Class Prediction: PROD_NUM
# Data: 60, Class Prediction: OTHER
# Data: 30, Class Prediction: OTHER
# Data: 229, Class Prediction: OTHER
# Data: 60, Class Prediction: OTHER
# Data: 110, Class Prediction: OTHER
# Data: 260, Class Prediction: PROD_NUM
# Data: 37, Class Prediction: PROD_NUM
# Data: 89, Class Prediction: OTHER
# Data: 160, Class Prediction: OTHER
# Data: 139, Class Prediction: PROD_NUM
# Data: 249, Class Prediction: PROD_NUM
# Data: 169, Class Prediction: PROD_NUM
# Data: 140, Class Prediction: OTHER
# Data: 269, Class Prediction: PROD_NUM
# Data: 139, Class Prediction: PROD_NUM
# Data: 145, Class Prediction: OTHER
# Data: 99, Class Prediction: OTHER
# Data: 239, Class Prediction: PROD_NUM
# Data: 65, Class Prediction: OTHER
# Data: 45, Class Prediction: PROD_NUM
# Data: 449, Class Prediction: PROD_NUM
# Data: 381.6, Class Prediction: OTHER
# Data: 799, Class Prediction: PROD_NUM
# Data: 210, Class Prediction: PROD_NUM
# Data: 59, Class Prediction: PROD_NUM
# Data: 159, Class Prediction: OTHER
# Data: 249, Class Prediction: PROD_NUM
# Data: 95, Class Prediction: OTHER
# Data: 99, Class Prediction: OTHER
# Data: 359, Class Prediction: OTHER
# Data: 289, Class Prediction: OTHER
# Data: 219, Class Prediction: PROD_NUM
# Data: 129, Class Prediction: OTHER
# Data: 79, Class Prediction: OTHER
# Data: 139, Class Prediction: PROD_NUM
# Data: 45, Class Prediction: PROD_NUM
# Data: 140, Class Prediction: OTHER
# Data: 60, Class Prediction: OTHER
# Data: 79, Class Prediction: OTHER
# Data: 20, Class Prediction: OTHER
# Data: 135, Class Prediction: PROD_NUM
# Data: 249, Class Prediction: PROD_NUM
# Data: 99, Class Prediction: OTHER
# Data: 28, Class Prediction: OTHER
# Data: 105, Class Prediction: OTHER
# Data: 105, Class Prediction: OTHER
# Data: 170, Class Prediction: OTHER
# Data: 360, Class Prediction: PROD_NUM
# Data: 99, Class Prediction: OTHER
# Data: 87.2, Class Prediction: OTHER
# Data: 25, Class Prediction: PROD_NUM
# Data: 30, Class Prediction: OTHER
# Data: 10, Class Prediction: PROD_NUM
# Data: 95, Class Prediction: OTHER
# Data: 210, Class Prediction: PROD_NUM
# Data: 119, Class Prediction: PROD_NUM
# Data: 660, Class Prediction: OTHER
# Data: 49, Class Prediction: PROD_NUM
# ----------Column Mapping Summary----------
# column predictions: ['PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'OTHER', 'PROD_NUM', 'PROD_NUM', 'OTHER', 'PROD_NUM']
# predicted class: OTHER
# number of classifications: 58
# actual class: OTHER
# OTHER is the Majority Predicted Class.
# The majority class is: OTHER; 58 of 100 predictions.
# Original Class: Pris
# ________________________________________________
# ----------Mapping column 5 of 18----------
# Data: 8.13E+11, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 5.70E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: nan, Class Prediction: PROD_NUM
# Data: 43377761754, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 7.31E+12, Class Prediction: PROD_NUM
# Data: 5.06E+12, Class Prediction: PROD_NUM
# Data: 5.05E+12, Class Prediction: PROD_NUM
# Data: 3.61E+12, Class Prediction: PROD_NUM
# Data: 7.34E+12, Class Prediction: PROD_NUM
# Data: 8.01E+11, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 8.72E+12, Class Prediction: PROD_NUM
# Data: 8.72E+12, Class Prediction: PROD_NUM
# Data: 9.01E+12, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 7.39E+12, Class Prediction: PROD_NUM
# Data: 3.35E+12, Class Prediction: PROD_NUM
# Data: 4.26E+12, Class Prediction: PROD_NUM
# Data: 7.35E+12, Class Prediction: PROD_NUM
# Data: 4.00E+12, Class Prediction: PROD_NUM
# Data: 5.70E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 4.89E+12, Class Prediction: PROD_NUM
# Data: 7.32E+12, Class Prediction: PROD_NUM
# Data: 9.42E+12, Class Prediction: PROD_NUM
# Data: 8421364787, Class Prediction: PROD_NUM
# Data: 3.61E+12, Class Prediction: PROD_NUM
# Data: 4.90E+12, Class Prediction: PROD_NUM
# Data: 4.89E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 5.70E+12, Class Prediction: PROD_NUM
# Data: 5.03E+12, Class Prediction: PROD_NUM
# Data: 9.01E+12, Class Prediction: PROD_NUM
# Data: 9.34E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 5.05E+12, Class Prediction: PROD_NUM
# Data: 5.70E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 4.02E+12, Class Prediction: PROD_NUM
# Data: 9.78E+12, Class Prediction: PROD_NUM
# Data: 8.72E+12, Class Prediction: PROD_NUM
# Data: 8.03E+12, Class Prediction: PROD_NUM
# Data: 6.43E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 3.03E+12, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 7.34E+12, Class Prediction: PROD_NUM
# Data: 6.93E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 5.70E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 45496420543, Class Prediction: PROD_NUM
# Data: 6.92E+12, Class Prediction: OTHER
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 3.35E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 5.03E+12, Class Prediction: PROD_NUM
# Data: 6.43E+12, Class Prediction: PROD_NUM
# Data: 5.06E+12, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 6.61E+11, Class Prediction: PROD_NUM
# Data: 4.06E+12, Class Prediction: PROD_NUM
# Data: 8.05E+12, Class Prediction: PROD_NUM
# Data: 3.14E+12, Class Prediction: PROD_NUM
# Data: 5.06E+12, Class Prediction: PROD_NUM
# Data: 4.06E+12, Class Prediction: PROD_NUM
# Data: 5.06E+12, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 8.71E+12, Class Prediction: PROD_NUM
# Data: 8.00E+12, Class Prediction: PROD_NUM
# Data: 7.33E+12, Class Prediction: PROD_NUM
# Data: 5.02E+12, Class Prediction: PROD_NUM
# Data: 4.01E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 8.88E+11, Class Prediction: PROD_NUM
# Data: 3.31E+12, Class Prediction: PROD_NUM
# Data: 7.33E+12, Class Prediction: PROD_NUM
# Data: 7.35E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# Data: 5.06E+11, Class Prediction: PROD_NUM
# Data: 8.41E+11, Class Prediction: PROD_NUM
# Data: 5.74E+12, Class Prediction: PROD_NUM
# Data: 5.71E+12, Class Prediction: PROD_NUM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-7f6ddf156f31> in <module>
#       1 for i in range(len(list_files)):
# ----> 2     evaluate(i)
#       3 #evaluate(0)
#       4 #evaluate(1)
#       5
#
# <ipython-input-11-14d7267df8aa> in evaluate(num)
#      90                 predicted_class = 'OTHER'
#      91             else:
# ---> 92                 predicted_class = predictClass(data, tokenizer, model)
#      93             predictions_map[n].append(predicted_class)
#      94             predictions_only[n].append(predicted_class)
#
# <ipython-input-11-14d7267df8aa> in predictClass(text, tok, model)
#      29 def predictClass(text, tok, model):
#      30     text_pad = sequence.pad_sequences(tok.texts_to_sequences([text]), maxlen=300)
# ---> 31     predict_x = model.predict(text_pad)
#      32     predict_class = np.argmax(predict_x, axis=1)
#      33     score = le.inverse_transform(predict_class)
#
# c:\users\mail\pycharmprojects\saleship\venv\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# c:\users\mail\pycharmprojects\saleship\venv\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\users\mail\pycharmprojects\saleship\venv\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# c:\users\mail\pycharmprojects\saleship\venv\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# c:\users\mail\pycharmprojects\saleship\venv\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# c:\users\mail\pycharmprojects\saleship\venv\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# c:\users\mail\pycharmprojects\saleship\venv\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print('EVAL', eval_list)
print('OVERALL', percent_list)
average_total_autoperf = statistics.mean(percent_list)
print('Average automation percentage:', average_total_autoperf)
